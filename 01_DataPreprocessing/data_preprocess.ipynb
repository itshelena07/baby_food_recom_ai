# %% [markdown]
# <h3><strong>Data Preprocessing</strong></h3>

# %% [markdown]
# <p><strong>Data Preparation</strong></p>

# %%
#Open Excel File
import openpyxl
import os

# Load the workbook
workbook = openpyxl.load_workbook('dataset.xlsx')

# Select the active worksheet
worksheet = workbook["Sheet1"]

# %%
# Import pandas for data manipulation
import pandas as pd
import numpy as np

data = []
headers = []

# Get headers from the first row
for col in range(1, worksheet.max_column + 1):
    headers.append(worksheet.cell(row=1, column=col).value)

# Get data from remaining rows
for row in range(2, worksheet.max_row + 1):
    row_data = []
    for col in range(1, worksheet.max_column + 1):
        row_data.append(worksheet.cell(row=row, column=col).value)
    data.append(row_data)

# Create DataFrame
df = pd.DataFrame(data, columns=headers)

print(headers)

# Display first few rows to verify
print(f"Dataset shape: {df.shape}")
df.head()
# Out:
# ['food_name', 'ingredient', 'cleaned_check', 'ner_ingredient', 'instructions', 'min_age_group', 'max_age_group', 'texture', 'prep_time', 'cook_time', 'serving', 'choking_hazard', 'origin', 'recipe_link', 'credibility', 'image_link', 'region', 'flag_code', 'difficulty', 'meal_type', 'description', 'dietary_tags', 'tips', 'allergen', 'hypoallergenic', 'nutrition_value']
# Dataset shape: (1182, 26)
#                                     food_name  \
# 0  Edamame and Sweet Potato Dumplings (Oyaki)
# 1  Chicken, Carrot, and Onion Udon For Babies
# 2                               Kinaki Yogurt
# 3              Natto Oyaki and Grilled Salmon
# 4                                   Miso Soup
#
#                                           ingredient  \
# 0  - 30 g of sweet potato\n- 20 g of edamame\n- 5...
# 1  - 10 g of onion\n- 10 g of chicken breast (pre...
# 2  - 2-3 tablespoons of plain yogurt \n- A pinch ...
# 3  Natto Oyaki :\n- 200g Japanese rice *steamed\n...
# 4  - 120 ml of dashi \n- 20 grams of tofu \n- 1/4...
#
#                                        cleaned_check  \
# 0  ['sweet potato', 'edamame', 'cornstarch', 'wat...
# 1  ['onion', 'chicken breast', 'udon thin', 'dash...
# 2                        ['yogurt', 'soybean flour']
# 3  ['japanese rice', ' natto', 'long onion', 'egg...
# 4                    ['dashi', 'tofu', 'miso paste']
#
#                                       ner_ingredient  \
# 0  ['1sweet potato', 'edamame', 'cornstarch', 'wa...
# 1  ['onion', 'chicken breast', 'udon thin', 'dash...
# 2                 ['yogurt', 'soybean flour kinako']
# 3  ['japanese rice', 'pack natto', 'long onion', ...
# 4                    ['dashi', 'tofu', 'miso paste']
#
#                                         instructions  min_age_group  \
# 0  1. Steam the sweet potato until it's soft (abo...              7
# 1  1. Finely chop the carrot and onion.\n2. Finel...              7
# 2  1. Put the yogurt into a small dish.\n2. Sprin...              7
# 3  Natto Oyaki :\n1. mix rice, butter and natto i...             12
# 4  1. Bring 120 ml of water to a boil in a pot an...              7
#
#    max_age_group texture  prep_time  cook_time  ... region flag_code  \
# 0              8    None       10.0        5.0  ...   None      None
# 1              8    None        5.0        6.0  ...   None      None
# 2              8    None        2.0        3.0  ...   None      None
# 3             12    None        NaN        NaN  ...   None      None
# 4              8    None        2.0        3.0  ...   None      None
#
#   difficulty meal_type description dietary_tags  tips allergen hypoallergenic  \
# 0       None      None        None         None  None     None           None
# 1       None      None        None         None  None     None           None
# 2       None      None        None         None  None     None           None
# 3       None      None        None         None  None     None           None
# 4       None      None        None         None  None     None           None
#
#   nutrition_value
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
#
# [5 rows x 26 columns]

# %%
# Display all column names to verify
print("Column names:", df.columns.tolist())

# Drop None value column if it exists
none_columns = [col for col in df.columns if col is None]
if none_columns:
    df = df.drop(columns=none_columns)
    print(f"Dropped {len(none_columns)} None column(s)")

# Display all column names to verify
print("Column post-clean:", df.columns.tolist())
print(f"Dataset shape: {df.shape}")
# Out:
# Column names: ['food_name', 'ingredient', 'cleaned_check', 'ner_ingredient', 'instructions', 'min_age_group', 'max_age_group', 'texture', 'prep_time', 'cook_time', 'serving', 'choking_hazard', 'origin', 'recipe_link', 'credibility', 'image_link', 'region', 'flag_code', 'difficulty', 'meal_type', 'description', 'dietary_tags', 'tips', 'allergen', 'hypoallergenic', 'nutrition_value']
# Column post-clean: ['food_name', 'ingredient', 'cleaned_check', 'ner_ingredient', 'instructions', 'min_age_group', 'max_age_group', 'texture', 'prep_time', 'cook_time', 'serving', 'choking_hazard', 'origin', 'recipe_link', 'credibility', 'image_link', 'region', 'flag_code', 'difficulty', 'meal_type', 'description', 'dietary_tags', 'tips', 'allergen', 'hypoallergenic', 'nutrition_value']
# Dataset shape: (1182, 26)

# %%
#renamed columns
df = df.rename(columns={
    'Food Name' : 'food_name',
    'Ingredients' : 'ingredient',
    'Instructions' : 'instructions',
    'Min Age Group ': 'min_age_group',
    'Max Age Group ': 'max_age_group',
    'NER Ingredient': 'ner_ingredient',
    'Texture': 'texture',
    'Prep Time': 'prep_time',
    'Cook Time': 'cook_time',
    'Serving': 'serving',
    'Difficulty': 'difficulty',
    'Origin': 'origin',
    'Region': 'region',
    'Description': 'description',
    'Image Link ': 'image_link',
    'Link ': 'recipe_link',
    'Credibility ': 'credibility',
    'Meal Type': 'meal_type',
    'Flavor_type': 'flavor_type',
    'Dietary Tags': 'dietary_tags',
    'Choking Hazards': 'choking_hazards',
    'Nutrion Value': 'nutrition_value',
    'tips': 'tips',
    'Allergen': 'allergen',
    'Hypoallergenic': 'hypoallergenic',
})

print("Column name post-clean:", df.columns.tolist())
df.head()
# Out:
# Column name post-clean: ['food_name', 'ingredient', 'cleaned_check', 'ner_ingredient', 'instructions', 'min_age_group', 'max_age_group', 'texture', 'prep_time', 'cook_time', 'serving', 'choking_hazard', 'origin', 'recipe_link', 'credibility', 'image_link', 'region', 'flag_code', 'difficulty', 'meal_type', 'description', 'dietary_tags', 'tips', 'allergen', 'hypoallergenic', 'nutrition_value']
#                                     food_name  \
# 0  Edamame and Sweet Potato Dumplings (Oyaki)
# 1  Chicken, Carrot, and Onion Udon For Babies
# 2                               Kinaki Yogurt
# 3              Natto Oyaki and Grilled Salmon
# 4                                   Miso Soup
#
#                                           ingredient  \
# 0  - 30 g of sweet potato\n- 20 g of edamame\n- 5...
# 1  - 10 g of onion\n- 10 g of chicken breast (pre...
# 2  - 2-3 tablespoons of plain yogurt \n- A pinch ...
# 3  Natto Oyaki :\n- 200g Japanese rice *steamed\n...
# 4  - 120 ml of dashi \n- 20 grams of tofu \n- 1/4...
#
#                                        cleaned_check  \
# 0  ['sweet potato', 'edamame', 'cornstarch', 'wat...
# 1  ['onion', 'chicken breast', 'udon thin', 'dash...
# 2                        ['yogurt', 'soybean flour']
# 3  ['japanese rice', ' natto', 'long onion', 'egg...
# 4                    ['dashi', 'tofu', 'miso paste']
#
#                                       ner_ingredient  \
# 0  ['1sweet potato', 'edamame', 'cornstarch', 'wa...
# 1  ['onion', 'chicken breast', 'udon thin', 'dash...
# 2                 ['yogurt', 'soybean flour kinako']
# 3  ['japanese rice', 'pack natto', 'long onion', ...
# 4                    ['dashi', 'tofu', 'miso paste']
#
#                                         instructions  min_age_group  \
# 0  1. Steam the sweet potato until it's soft (abo...              7
# 1  1. Finely chop the carrot and onion.\n2. Finel...              7
# 2  1. Put the yogurt into a small dish.\n2. Sprin...              7
# 3  Natto Oyaki :\n1. mix rice, butter and natto i...             12
# 4  1. Bring 120 ml of water to a boil in a pot an...              7
#
#    max_age_group texture  prep_time  cook_time  ... region flag_code  \
# 0              8    None       10.0        5.0  ...   None      None
# 1              8    None        5.0        6.0  ...   None      None
# 2              8    None        2.0        3.0  ...   None      None
# 3             12    None        NaN        NaN  ...   None      None
# 4              8    None        2.0        3.0  ...   None      None
#
#   difficulty meal_type description dietary_tags  tips allergen hypoallergenic  \
# 0       None      None        None         None  None     None           None
# 1       None      None        None         None  None     None           None
# 2       None      None        None         None  None     None           None
# 3       None      None        None         None  None     None           None
# 4       None      None        None         None  None     None           None
#
#   nutrition_value
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
#
# [5 rows x 26 columns]

# %% [markdown]
# <p>Checking Any Null Value</p>

# %%
# check every column for null values
for col in df.columns:
    null_count = df[col].isnull().sum()
    if null_count > 0:
        print(f"Column '{col}' has {null_count} null values.")
    else:
        print(f"Column '{col}' has no null values.")
# Out:
# Column 'food_name' has no null values.
# Column 'ingredient' has no null values.
# Column 'cleaned_check' has 555 null values.
# Column 'ner_ingredient' has 377 null values.
# Column 'instructions' has no null values.
# Column 'min_age_group' has no null values.
# Column 'max_age_group' has no null values.
# Column 'texture' has 1182 null values.
# Column 'prep_time' has 444 null values.
# Column 'cook_time' has 433 null values.
# Column 'serving' has 105 null values.
# Column 'choking_hazard' has 1182 null values.
# Column 'origin' has 278 null values.
# Column 'recipe_link' has no null values.
# Column 'credibility' has 872 null values.
# Column 'image_link' has 1140 null values.
# Column 'region' has 1182 null values.
# Column 'flag_code' has 1182 null values.
# Column 'difficulty' has 1182 null values.
# Column 'meal_type' has 983 null values.
# Column 'description' has 1051 null values.
# Column 'dietary_tags' has 1182 null values.
# Column 'tips' has 1158 null values.
# Column 'allergen' has 1182 null values.
# Column 'hypoallergenic' has 1182 null values.
# Column 'nutrition_value' has 423 null values.

# %%
#drop data if imporant columns are empty
important_columns = ['food_name', 'ingredient', 'instructions', 'recipe_link']
for col in df.columns:
    if col in important_columns:
        null_count = df[col].isnull().sum()        
        if null_count >0:
            df = df.dropna(subset=[col])

# After dropping rows, you may want to reset the index if needed
df = df.reset_index(drop=True)
# Display the cleaned DataFrame
print("Cleaned DataFrame:")
print(df.shape)
df.head(10)
# Out:
# Cleaned DataFrame:
# (1182, 26)
#                                      food_name  \
# 0   Edamame and Sweet Potato Dumplings (Oyaki)
# 1   Chicken, Carrot, and Onion Udon For Babies
# 2                                Kinaki Yogurt
# 3               Natto Oyaki and Grilled Salmon
# 4                                    Miso Soup
# 5                               Zucchini puree
# 6                         Apple and pear sauce
# 7                     Baby oatmeal with prunes
# 8  Yellow Sweet Potato Puree (Pure Ubi Kuning)
# 9                   Vegetable and Cheese Puree
#
#                                           ingredient  \
# 0  - 30 g of sweet potato\n- 20 g of edamame\n- 5...
# 1  - 10 g of onion\n- 10 g of chicken breast (pre...
# 2  - 2-3 tablespoons of plain yogurt \n- A pinch ...
# 3  Natto Oyaki :\n- 200g Japanese rice *steamed\n...
# 4  - 120 ml of dashi \n- 20 grams of tofu \n- 1/4...
# 5          - 1 medium zucchini\n- trimmed and sliced
# 6  - 1 apple, such as Pink Lady or Honeycrisp\n- ...
# 7  - ¼ cup (1 oz/30 g) baby oatmeal\n- 4 pitted p...
# 8  - 50g yellow sweet potato \n- Breast milk or f...
# 9  - 1 cup finely chopped carrot \n- ½ cup finely...
#
#                                        cleaned_check  \
# 0  ['sweet potato', 'edamame', 'cornstarch', 'wat...
# 1  ['onion', 'chicken breast', 'udon thin', 'dash...
# 2                        ['yogurt', 'soybean flour']
# 3  ['japanese rice', ' natto', 'long onion', 'egg...
# 4                    ['dashi', 'tofu', 'miso paste']
# 5                                       ['zucchini']
# 6         ['apple pink lady',  'honeycrisp', 'pear']
# 7                          ['baby oatmeal', 'prune']
# 8  ['yellow sweet potato', 'breast milk ','formul...
# 9  carrot, potato, cheese, coriander, oil, water,...
#
#                                       ner_ingredient  \
# 0  ['1sweet potato', 'edamame', 'cornstarch', 'wa...
# 1  ['onion', 'chicken breast', 'udon thin', 'dash...
# 2                 ['yogurt', 'soybean flour kinako']
# 3  ['japanese rice', 'pack natto', 'long onion', ...
# 4                    ['dashi', 'tofu', 'miso paste']
# 5                                   ['zucchini', '']
# 6    ['apple pink lady honeycrisp', 'pear bartlett']
# 7                     ['baby oatmeal', 'prune plum']
# 8     ['yellow sweet potato', 'breast milk formula']
# 9                                               None
#
#                                         instructions  min_age_group  \
# 0  1. Steam the sweet potato until it's soft (abo...              7
# 1  1. Finely chop the carrot and onion.\n2. Finel...              7
# 2  1. Put the yogurt into a small dish.\n2. Sprin...              7
# 3  Natto Oyaki :\n1. mix rice, butter and natto i...             12
# 4  1. Bring 120 ml of water to a boil in a pot an...              7
# 5  1. In a saucepan over medium-high heat, bring ...              6
# 6  1. Peel, quarter, and core the apple and pear....              6
# 7  1. Make the baby oatmeal according to the dire...              6
# 8  1. Wash and peel sweet potato. \n2. Dice and s...              6
# 9  1. Clean vegetables. \n2. Cook vegetables with...              6
#
#    max_age_group texture  prep_time  cook_time  ... region flag_code  \
# 0              8    None       10.0        5.0  ...   None      None
# 1              8    None        5.0        6.0  ...   None      None
# 2              8    None        2.0        3.0  ...   None      None
# 3             12    None        NaN        NaN  ...   None      None
# 4              8    None        2.0        3.0  ...   None      None
# 5              8    None        NaN        NaN  ...   None      None
# 6              8    None        NaN        NaN  ...   None      None
# 7              8    None        NaN        NaN  ...   None      None
# 8             24    None       10.0       15.0  ...   None      None
# 9              8    None        NaN       30.0  ...   None      None
#
#   difficulty meal_type description dietary_tags  tips allergen hypoallergenic  \
# 0       None      None        None         None  None     None           None
# 1       None      None        None         None  None     None           None
# 2       None      None        None         None  None     None           None
# 3       None      None        None         None  None     None           None
# 4       None      None        None         None  None     None           None
# 5       None      None        None         None  None     None           None
# 6       None      None        None         None  None     None           None
# 7       None      None        None         None  None     None           None
# 8       None      None        None         None  None     None           None
# 9       None      None        None         None  None     None           None
#
#                                      nutrition_value
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8                                               None
# 9  - Calories: 652.5 kcal \n- Carbohydrates: 64.9...
#
# [10 rows x 26 columns]

# %%
df['dietary_tags'] = ''
df['choking_hazards'] = ''
df['difficulty'] = ''
df['allergen'] = ''
df['hypoallergenic'] = ''

# %%
df_real = df.copy()
df.shape
# Out:
# (1182, 26)

# %% [markdown]
# <p>Formatting Ingredient and Instruction</p>

# %%
import re

def is_already_formatted(text):
    return '\n' in text or '\\n' in text

# %%
# --- Normalize Ingredients ---
def normalize_ingredients(text):
    if is_already_formatted(text):
        return text.replace('\n', '\\n') if '\n' in text else text

    lines = []
    text = re.sub(r'\s+', ' ', text).strip()

    # Try splitting by common delimiters
    if ' - ' in text:
        parts = text.split(' - ')
    elif '•' in text:
        parts = [p.strip() for p in text.split('•') if p.strip()]
    elif ',' in text:
        parts = [p.strip() for p in text.split(',') if p.strip()]
    elif re.search(r'\d+\. ', text):
        parts = re.split(r'\d+\. ', text)
    else:
        parts = [text]

    for part in parts:
        part = re.sub(r'^\d+\. ?', '', part).strip()
        if part:
            lines.append('- ' + part)

    return '\\n'.join(lines)

# %%
# --- Normalize Instructions ---
def normalize_instructions(text):
    if is_already_formatted(text):
        return text.replace('\n', '\\n') if '\n' in text else text

    lines = []
    text = re.sub(r'\r\n|\r', '\n', text).strip()

    # Match numbered or step-based patterns
    step_pattern = r'(?:Step\s*\d+:\s*|\d+\.\s*)([^:.]+?)(?=\s*(?:Step\s*\d+:\s*|\d+\.\s*|$))'
    matches = re.findall(step_pattern, text, re.IGNORECASE)

    if matches:
        parts = [m.strip() for m in matches if m.strip()]
    else:
        # Split by sentences
        parts = re.split(r'(?<=[.!?])\s+', text)

    for i, part in enumerate(parts):
        part = re.sub(r'\s+', ' ', part).strip()
        if part:
            lines.append(f"{i+1}. {part}")

    return '\\n'.join(lines)

# %%
# Normalize the 'ingredient' and 'instructions' columns
df['ingredient'] = df['ingredient'].apply(normalize_ingredients)
df['instructions'] = df['instructions'].apply(normalize_instructions)

df_real[['ingredient','instructions']].head()
print("Normalized DataFrame:")
df[['ingredient','instructions']].head()
# Out:
# Normalized DataFrame:
#                                           ingredient  \
# 0  - 30 g of sweet potato\n- 20 g of edamame\n- 5...
# 1  - 10 g of onion\n- 10 g of chicken breast (pre...
# 2  - 2-3 tablespoons of plain yogurt \n- A pinch ...
# 3  Natto Oyaki :\n- 200g Japanese rice *steamed\n...
# 4  - 120 ml of dashi \n- 20 grams of tofu \n- 1/4...
#
#                                         instructions
# 0  1. Steam the sweet potato until it's soft (abo...
# 1  1. Finely chop the carrot and onion.\n2. Finel...
# 2  1. Put the yogurt into a small dish.\n2. Sprin...
# 3  Natto Oyaki :\n1. mix rice, butter and natto i...
# 4  1. Bring 120 ml of water to a boil in a pot an...

# %% [markdown]
# <p>Extract Ingredient Name</p>

# %%
import re
import spacy
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords as nltk_stopwords

# Load spaCy model and lemmatizer
nlp = spacy.load("en_core_web_sm")
lemmatizer = WordNetLemmatizer()

# %%
custom_stopwords = {
    # Common general stopwords
    "a", "an", "the", "of", "to", "and", "in", "on", "for", "with", "by",
    "as", "at", "be", "is", "was", "are", "were", "it", "this", "that",

    # Recipe-specific words
    "finely", "stalk", "optional", "pinch", "dash", "sprinkle", "to taste", "fresh", "ripe",
    "whole", "cut", "slice", "diced", "chopped", "grated", "crushed",
    "halved", "quartered", "peeled", "mashed", "blended", "cooked",
    "steamed", "boiled", "baked", "roasted", "toasted", "minced", "pureed",
    "thinly", "soft", "ripe", "unsalted", "lowfat", "low-fat", "plain",
    "unsweetened", "organic", "natural", "canned", "frozen", "freshly",
    "ground", "powder", "sized", "pieces", "piece", "part", "parts",
    "measure", "measured", "add", "mix", "combine", "stir", "fold",
    "whisk", "blend", "mash", "chop", "dice", "grate", "steam", "boil",
    "bake", "roast", "toast", "mince", "puree", "soak", "rinse", "drain",
    "preheat", "oven", "medium", "high", "low", "heat", "temperature",
    "minutes", "minute", "hours", "hour", "time", "until", "softened",
    "cooled", "warm", "room temperature", "raw", "uncooked", "cooked",
    "leftover", "any kind", "preferably", "fresh", "store-bought",
    "homemade", "prepared", "ready-to-use", "instant", "cubed", "thin slices",
    "small", "medium", "large", "few", "bit", "bits", "drop", "drops"
}

# Combine with NLTK's English stopwords
STOPWORDS = set(nltk_stopwords.words('english')).union(custom_stopwords)

# %%
import nltk


def extract_clean_ingredient(line):

    nltk.download('wordnet')
    
    """
    Extracts and cleans a single ingredient line from a baby recipe.

    Args:
        line (str): Raw ingredient line like "- 1 ripe banana"

    Returns:
        str: Cleaned ingredient name like "banana"
    """

    # Step 1: Remove numbers and fractions
    line = re.sub(r'\d+\/?\d*', '', line)

    # Step 2: Remove units of measurement (expanded list)
    line = re.sub(
        r'\b(g|gm|gms|gram|grams|kg|kgs|kilogram|kilograms|'
        r'mg|mgs|milligram|milligrams|'
        r'ml|mls|milliliter|milliliters|l|ls|liter|liters|'
        r'tsp|tsps|teaspoon|teaspoons|tbsp|tb|tbsps|tablespoon|tablespoons|'
        r'cup|cups|c|cs|'
        r'oz|ounce|ounces|'
        r'lb|lbs|pound|pounds|'
        r'metric teaspoon|metric tablespoons|'
        r'pinch|drops|handful|sprinkle)\b',
        '',
        line,
        flags=re.IGNORECASE
    )

    # Step 3: Strip symbols and normalize spaces
    line = re.sub(r'[\-\*\(\),]', '', line).strip()
    line = re.sub(r'\s+', ' ', line).lower().strip()

    # Step 4: Use spaCy to process the text
    doc = nlp(line)

    # Step 5: Tokenize, remove verbs and stopwords, lemmatize
    tokens = []
    for token in doc:
        lemma = lemmatizer.lemmatize(token.text, 'n')  # Lemmatize as noun
        if (
            token.pos_ != "VERB" and
            lemma.lower() not in STOPWORDS and
            token.is_alpha
        ):
            tokens.append(lemma.lower())

    return " ".join(tokens).strip()

# %%
def extract_ingredients(text):
    """
    Converts escaped newlines (\\n) to real ones, then extracts ingredients.
    Returns: List of cleaned ingredient names
    """
    try:
        text = text.encode().decode('unicode_escape')
    except Exception:
        pass

    ingredients = []
    for line in text.split('\n'):
        stripped = line.strip()
        if stripped.startswith('-'):
            ingredient = stripped[1:].strip()
            if ingredient:
                ingredients.append(ingredient)

    return ingredients

# %%
def process_ingredients(text):
    raw = extract_ingredients(text)
    cleaned = [extract_clean_ingredient(ing) for ing in raw]
    return cleaned

# Apply function to create new column
df['ner_ingredient'] = df['ingredient'].apply(process_ingredients)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# ...
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Helena\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df[['food_name', 'ingredient', 'cleaned_check', 'ner_ingredient']].head(10)
# Out:
#                                      food_name  \
# 0   Edamame and Sweet Potato Dumplings (Oyaki)
# 1   Chicken, Carrot, and Onion Udon For Babies
# 2                                Kinaki Yogurt
# 3               Natto Oyaki and Grilled Salmon
# 4                                    Miso Soup
# 5                               Zucchini puree
# 6                         Apple and pear sauce
# 7                     Baby oatmeal with prunes
# 8  Yellow Sweet Potato Puree (Pure Ubi Kuning)
# 9                   Vegetable and Cheese Puree
#
#                                           ingredient  \
# 0  - 30 g of sweet potato\n- 20 g of edamame\n- 5...
# 1  - 10 g of onion\n- 10 g of chicken breast (pre...
# 2  - 2-3 tablespoons of plain yogurt \n- A pinch ...
# 3  Natto Oyaki :\n- 200g Japanese rice *steamed\n...
# 4  - 120 ml of dashi \n- 20 grams of tofu \n- 1/4...
# 5          - 1 medium zucchini\n- trimmed and sliced
# 6  - 1 apple, such as Pink Lady or Honeycrisp\n- ...
# 7  - ¼ cup (1 oz/30 g) baby oatmeal\n- 4 pitted p...
# 8  - 50g yellow sweet potato \n- Breast milk or f...
# 9  - 1 cup finely chopped carrot \n- ½ cup finely...
#
#                                        cleaned_check  \
# 0  ['sweet potato', 'edamame', 'cornstarch', 'wat...
# 1  ['onion', 'chicken breast', 'udon thin', 'dash...
# 2                        ['yogurt', 'soybean flour']
# 3  ['japanese rice', ' natto', 'long onion', 'egg...
# 4                    ['dashi', 'tofu', 'miso paste']
# 5                                       ['zucchini']
# 6         ['apple pink lady',  'honeycrisp', 'pear']
# 7                          ['baby oatmeal', 'prune']
# 8  ['yellow sweet potato', 'breast milk ','formul...
# 9  carrot, potato, cheese, coriander, oil, water,...
#
#                                       ner_ingredient
# 0         [sweet potato, edamame, cornstarch, water]
# 1  [onion, chicken breast, udon thin, dashi babys...
# 2                     [yogurt, soybean flour kinako]
# 3  [japanese rice, pack natto, long onion, egg, b...
# 4                          [dashi, tofu, miso paste]
# 5                                       [zucchini, ]
# 6        [apple pink lady honeycrisp, pear bartlett]
# 7                         [baby oatmeal, prune plum]
# 8         [yellow sweet potato, breast milk formula]
# 9  [carrot, potato, cheese, coriander leaf, oil, ...

# %%
def convert_escaped_newlines(df):
    """
    Convert escaped newlines (\\n) to real newlines for Excel display
    """
    text_columns = ['ingredient', 'instructions', 'tips']
    
    for col in text_columns:
        if col in df.columns:
            # Replace escaped newlines with actual newlines
            df[col] = df[col].apply(
                lambda x: x.replace('\\n', '\n') if isinstance(x, str) else x
            )
    
    return df

# Apply the conversion right before saving
df = convert_escaped_newlines(df)

# Then save
df.to_excel("1st_dataset.xlsx", index=False)
print("✅ DataFrame saved to '1st_dataset.xlsx'")

# %% [markdown]
# **New Dataset After Checking NER INgredients**

# %%
#Open Excel File
import openpyxl
import os

# Load the workbook
workbook = openpyxl.load_workbook('cleaned_ner.xlsx')

# Select the active worksheet
worksheet = workbook["Sheet1"]
# Import pandas for data manipulation
import pandas as pd
import numpy as np

data = []
headers = []

# Get headers from the first row
for col in range(1, worksheet.max_column + 1):
    headers.append(worksheet.cell(row=1, column=col).value)

# Get data from remaining rows
for row in range(2, worksheet.max_row + 1):
    row_data = []
    for col in range(1, worksheet.max_column + 1):
        row_data.append(worksheet.cell(row=row, column=col).value)
    data.append(row_data)

# Create DataFrame
df = pd.DataFrame(data, columns=headers)

print(headers)

# Display first few rows to verify
print(f"Dataset shape: {df.shape}")
df.head()
# Out:
# ['food_name', 'ingredient', 'ner_ingredient', 'instructions', 'min_age_group', 'max_age_group', 'texture', 'prep_time', 'cook_time', 'serving', 'choking_hazard', 'origin', 'recipe_link', 'credibility', 'image_link', 'region', 'flag_code', 'difficulty', 'meal_type', 'description', 'dietary_tags', 'tips', 'allergen', 'hypoallergenic', 'nutrition_value', 'choking_hazards']
# Dataset shape: (1182, 26)
#                                     food_name  \
# 0  Edamame and Sweet Potato Dumplings (Oyaki)
# 1  Chicken, Carrot, and Onion Udon For Babies
# 2                               Kinaki Yogurt
# 3              Natto Oyaki and Grilled Salmon
# 4                                   Miso Soup
#
#                                           ingredient  \
# 0  - 30 g of sweet potato\n- 20 g of edamame\n- 5...
# 1  - 10 g of onion\n- 10 g of chicken breast (pre...
# 2  - 2-3 tablespoons of plain yogurt \n- A pinch ...
# 3  Natto Oyaki :\n- 200g Japanese rice *steamed\n...
# 4  - 120 ml of dashi \n- 20 grams of tofu \n- 1/4...
#
#                                       ner_ingredient  \
# 0  ['sweet potato', 'edamame', 'cornstarch', 'wat...
# 1  ['onion', 'chicken breast', 'udon thin', 'dash...
# 2                        ['yogurt', 'soybean flour']
# 3  ['japanese rice', ' natto', 'long onion', 'egg...
# 4                    ['dashi', 'tofu', 'miso paste']
#
#                                         instructions  min_age_group  \
# 0  1. Steam the sweet potato until it's soft (abo...              7
# 1  1. Finely chop the carrot and onion.\n2. Finel...              7
# 2  1. Put the yogurt into a small dish.\n2. Sprin...              7
# 3  Natto Oyaki :\n1. mix rice, butter and natto i...             12
# 4  1. Bring 120 ml of water to a boil in a pot an...              7
#
#    max_age_group        texture  prep_time  cook_time serving  ... flag_code  \
# 0              8          puree       10.0        5.0       1  ...   unknown
# 1              8           NONE        5.0        6.0    None  ...        jp
# 2              8          puree        2.0        3.0       1  ...        jp
# 3             12  lumpy texture        NaN        NaN       2  ...        jp
# 4              8           NONE        2.0        3.0       1  ...        jp
#
#   difficulty meal_type description  \
# 0     Medium      None        None
# 1     Medium      None        None
# 2       Easy      None        None
# 3     Medium      None        None
# 4     Medium      None        None
#
#                                         dietary_tags  tips  \
# 0  vegan, halal, dairy_free, egg_free, nut_free, ...  None
# 1  non_veg, halal, dairy_free, egg_free, soy_free...  None
# 2              vegetarian, halal, egg_free, nut_free  None
# 3  pescetarian, halal, egg_free, soy_free, nut_fr...  None
# 4  vegan, halal, dairy_free, egg_free, nut_free, ...  None
#
#                     allergen hypoallergenic nutrition_value choking_hazards
# 0                    ['soy']             No            None              No
# 1                         []            Yes            None              No
# 2  ['gluten', 'milk', 'soy']             No            None              No
# 3           ['fish', 'milk']             No            None             Yes
# 4                    ['soy']             No            None              No
#
# [5 rows x 26 columns]

# %%
#drop data if imporant columns are empty
important_columns = ['food_name', 'ingredient', 'ner_ingredient', 'instructions', 'recipe_link']
for col in df.columns:
    if col in important_columns:
        null_count = df[col].isnull().sum()        
        if null_count >0:
            df = df.dropna(subset=[col])

# After dropping rows, you may want to reset the index if needed
df = df.reset_index(drop=True)
# Display the cleaned DataFrame
print("Cleaned DataFrame:")
print(df.shape)
df.head(10)
# Out:
# Cleaned DataFrame:
# (800, 26)
#                                      food_name  \
# 0   Edamame and Sweet Potato Dumplings (Oyaki)
# 1   Chicken, Carrot, and Onion Udon For Babies
# 2                                Kinaki Yogurt
# 3               Natto Oyaki and Grilled Salmon
# 4                                    Miso Soup
# 5                               Zucchini puree
# 6                         Apple and pear sauce
# 7                     Baby oatmeal with prunes
# 8  Yellow Sweet Potato Puree (Pure Ubi Kuning)
# 9                   Vegetable and Cheese Puree
#
#                                           ingredient  \
# 0  - 30 g of sweet potato\n- 20 g of edamame\n- 5...
# 1  - 10 g of onion\n- 10 g of chicken breast (pre...
# 2  - 2-3 tablespoons of plain yogurt \n- A pinch ...
# 3  Natto Oyaki :\n- 200g Japanese rice *steamed\n...
# 4  - 120 ml of dashi \n- 20 grams of tofu \n- 1/4...
# 5          - 1 medium zucchini\n- trimmed and sliced
# 6  - 1 apple, such as Pink Lady or Honeycrisp\n- ...
# 7  - ¼ cup (1 oz/30 g) baby oatmeal\n- 4 pitted p...
# 8  - 50g yellow sweet potato \n- Breast milk or f...
# 9  - 1 cup finely chopped carrot \n- ½ cup finely...
#
#                                       ner_ingredient  \
# 0  ['sweet potato', 'edamame', 'cornstarch', 'wat...
# 1  ['onion', 'chicken breast', 'udon thin', 'dash...
# 2                        ['yogurt', 'soybean flour']
# 3  ['japanese rice', ' natto', 'long onion', 'egg...
# 4                    ['dashi', 'tofu', 'miso paste']
# 5                                       ['zucchini']
# 6         ['apple pink lady',  'honeycrisp', 'pear']
# 7                          ['baby oatmeal', 'prune']
# 8  ['yellow sweet potato', 'breast milk ','formul...
# 9  carrot, potato, cheese, coriander, oil, water,...
#
#                                         instructions  min_age_group  \
# 0  1. Steam the sweet potato until it's soft (abo...              7
# 1  1. Finely chop the carrot and onion.\n2. Finel...              7
# 2  1. Put the yogurt into a small dish.\n2. Sprin...              7
# 3  Natto Oyaki :\n1. mix rice, butter and natto i...             12
# 4  1. Bring 120 ml of water to a boil in a pot an...              7
# 5  1. In a saucepan over medium-high heat, bring ...              6
# 6  1. Peel, quarter, and core the apple and pear....              6
# 7  1. Make the baby oatmeal according to the dire...              6
# 8  1. Wash and peel sweet potato. \n2. Dice and s...              6
# 9  1. Clean vegetables. \n2. Cook vegetables with...              6
#
#    max_age_group        texture  prep_time  cook_time    serving  ...  \
# 0              8          puree       10.0        5.0          1  ...
# 1              8           NONE        5.0        6.0       None  ...
# 2              8          puree        2.0        3.0          1  ...
# 3             12  lumpy texture        NaN        NaN          2  ...
# 4              8           NONE        2.0        3.0          1  ...
# 5              8          puree        NaN        NaN       None  ...
# 6              8          puree        NaN        NaN       None  ...
# 7              8          puree        NaN        NaN       None  ...
# 8             24          puree       10.0       15.0     1 bowl  ...
# 9              8          puree        NaN       30.0  1 serving  ...
#
#   flag_code difficulty meal_type description  \
# 0   unknown     Medium      None        None
# 1        jp     Medium      None        None
# 2        jp       Easy      None        None
# 3        jp     Medium      None        None
# 4        jp     Medium      None        None
# 5        us       Easy      None        None
# 6        us       Easy      None        None
# 7        us       Easy      None        None
# 8        id       Easy      None        None
# 9        bt     Medium      None        None
#
#                                         dietary_tags  tips  \
# 0  vegan, halal, dairy_free, egg_free, nut_free, ...  None
# 1  non_veg, halal, dairy_free, egg_free, soy_free...  None
# 2              vegetarian, halal, egg_free, nut_free  None
# 3  pescetarian, halal, egg_free, soy_free, nut_fr...  None
# 4  vegan, halal, dairy_free, egg_free, nut_free, ...  None
# 5  vegan, halal, dairy_free, egg_free, soy_free, ...  None
# 6  vegetarian, halal, dairy_free, egg_free, soy_f...  None
# 7  vegan, halal, dairy_free, egg_free, soy_free, ...  None
# 8  vegetarian, halal, egg_free, soy_free, nut_fre...  None
# 9  vegetarian, halal, egg_free, soy_free, nut_fre...  None
#
#                     allergen hypoallergenic  \
# 0                    ['soy']             No
# 1                         []            Yes
# 2  ['gluten', 'milk', 'soy']             No
# 3           ['fish', 'milk']             No
# 4                    ['soy']             No
# 5                         []            Yes
# 6                         []            Yes
# 7                         []            Yes
# 8                   ['milk']             No
# 9                   ['milk']             No
#
#                                      nutrition_value choking_hazards
# 0                                               None              No
# 1                                               None              No
# 2                                               None              No
# 3                                               None             Yes
# 4                                               None              No
# 5                                               None              No
# 6                                               None              No
# 7                                               None              No
# 8                                               None              No
# 9  - Calories: 652.5 kcal \n- Carbohydrates: 64.9...              No
#
# [10 rows x 26 columns]

# %% [markdown]
# Reformatting NER Ingredient

# %%
import ast

def format_ner_ingredient(df):
    # First ensure ner_ingredient is properly parsed as a list
    df['ner_ingredient_list'] = df['ner_ingredient'].apply(
        lambda x: ast.literal_eval(x) if isinstance(x, str) and x.strip().startswith('[') else 
                 x if isinstance(x, list) else 
                 [str(x)] if x else []
    )
    
    # Convert list to comma-separated string
    df['ner_ingredient_csv'] = df['ner_ingredient_list'].apply(
        lambda x: ','.join(str(item) for item in x) if isinstance(x, list) else ''
    )
    
    # Replace the original column with the CSV format if needed
    # df['ner_ingredient'] = df['ner_ingredient_csv']
    
    return df

# Apply the function
df = format_ner_ingredient(df)

# Display the results
df[['food_name', 'ner_ingredient', 'ner_ingredient_csv']].head()
# Out:
#                                     food_name  \
# 0  Edamame and Sweet Potato Dumplings (Oyaki)
# 1  Chicken, Carrot, and Onion Udon For Babies
# 2                               Kinaki Yogurt
# 3              Natto Oyaki and Grilled Salmon
# 4                                   Miso Soup
#
#                                       ner_ingredient  \
# 0  ['1sweet potato', 'edamame', 'cornstarch', 'wa...
# 1  ['onion', 'chicken breast', 'udon thin', 'dash...
# 2                 ['yogurt', 'soybean flour kinako']
# 3  ['japanese rice', 'pack natto', 'long onion', ...
# 4                    ['dashi', 'tofu', 'miso paste']
#
#                                   ner_ingredient_csv
# 0             1sweet potato,edamame,cornstarch,water
# 1  onion,chicken breast,udon thin,dashi babysafe ...
# 2                        yogurt,soybean flour kinako
# 3  japanese rice,pack natto,long onion,egg,butter...
# 4                              dashi,tofu,miso paste

# %%
import sys
import os

# Go into 'processing-technique' folder and add it to Python path
processing_dir = os.path.join(os.getcwd(), "preprocessing_techniques")
sys.path.append(processing_dir)

# %% [markdown]
# <p>Formatting Min and Max Age Group</p>

# %%
#ensure the min and max age only contain integers
import re 
from openpyxl.styles import PatternFill


def format_age(value):
    match = re.search(r'\d+', str(value))
    if match:
        return int(match.group())
    return None

df['min_age_group'] = df['min_age_group'].apply(format_age)
df['max_age_group'] = df['max_age_group'].apply(format_age)

print("====Results after formatting====")
df[['min_age_group','max_age_group']].head()
# Out:
# ====Results after formatting====
#    min_age_group  max_age_group
# 0              7              8
# 1              7              8
# 2              7              8
# 3             12             12
# 4              7              8

# %%
# Now you can import age_label from mapper
from mappers.age_label import age_rules
from pprint import pprint

pprint(age_rules)
# Out:
# {'age_keywords': {'chopped': {'max_age': 36,
#                               'min_age': 10,
#                               'reason': 'Small soft pieces for chewing '
#                                         'practice'},
#                   'finger food': {'max_age': 36,
#                                   'min_age': 8,
#                                   'reason': 'Self-feeding for older babies'},
#                   'mash': {'max_age': 10,
#                            'min_age': 6,
#                            'reason': 'Lumpy texture for advancing skills'},
#                   'porridge': {'max_age': 12,
#                                'min_age': 4,
#                                'reason': 'Easy-to-swallow grains'},
#                   'puree': {'max_age': 8,
#                             'min_age': 4,
#                             'reason': 'Smooth texture for early weaning'},
#                   'stew': {'max_age': 36,
#                            'min_age': 6,
#                            'reason': 'Soft, mixed textures'}},
#  'ingredient_rules': {'cow milk (as drink)': {'min_age': 12,
#                                               'reason': 'Not recommended as '
#                                                         'main drink under 12 '
#                                                         'months'},
#                       'grapes (whole)': {'min_age': 24,
#                                          'reason': 'Choking risk; always '
#                                                    'quarter'},
#                       'honey': {'min_age': 12,
#                                 'reason': 'Risk of infant botulism'},
#                       'peanut butter': {'min_age': 6,
#                                         'reason': 'Introduce as smooth paste '
#                                                   '(allergy guidelines)'},
#                       'salt': {'min_age': 12,
#                                'reason': 'Avoid added salt for babies'},
#                       'shellfish': {'min_age': 12,
#                                     'reason': 'High allergen risk'},
#                       'sugar': {'min_age': 12,
#                                 'reason': 'Avoid added sugars for babies'},
#                       'whole nuts': {'min_age': 36,
#                                      'reason': 'Choking hazard'}},
#  'instruction_keywords': {'blend until smooth': {'max_age': 6,
#                                                  'min_age': 4,
#                                                  'reason': 'Stage 1 puree'},
#                           'chop into small pieces': {'min_age': 8,
#                                                      'reason': 'Finger food '
#                                                                'for '
#                                                                'self-feeding'},
#                           'grate': {'min_age': 8,
#                                     'reason': 'Soft grated textures'},
#                           'mash with a fork': {'max_age': 8,
#                                                'min_age': 6,
#                                                'reason': 'Lumpy texture'},
#                           'steam until soft': {'min_age': 6,
#                                                'reason': 'Soft, dissolvable '
#                                                          'texture'}},
#  'texture_to_age': {'family_food': {'max_age': 36, 'min_age': 12},
#                     'finger_food': {'max_age': 36, 'min_age': 8},
#                     'lumpy': {'max_age': 8, 'min_age': 6},
#                     'smooth': {'max_age': 6, 'min_age': 4}}}

# %%
def infer_age(recipe_name, ingredients, instructions):
    # Initialize min_age and reasons
    min_age = 6   # Default baby age start (in months)
    max_age = 12  # Default upper limit (3 years)
    reasons = []

    # 1. Check recipe name keywords
    for keyword in age_rules["age_keywords"]:
        if keyword.lower() in recipe_name.lower():
            rule = age_rules["age_keywords"][keyword]
            if rule.get("min_age", 0) > min_age:
                min_age = rule["min_age"]
                reasons.append(f"Recipe name suggests '{keyword}' ({rule['reason']})")
            if "max_age" in rule:
                max_age = min(max_age, rule["max_age"])  # Tighten max if rule restricts it

    # 2. Check ingredient restrictions
    for ingredient in ingredients.split(','):
        ing_key = ingredient.strip().lower()
        if ing_key in age_rules["ingredient_rules"]:
            rule = age_rules["ingredient_rules"][ing_key]
            if rule.get("min_age", 0) > min_age:
                min_age = rule["min_age"]
                reasons.append(f"Ingredient '{ing_key}' requires {rule['reason']}")

    # 3. Check instructions for texture keywords
    for keyword in age_rules["instruction_keywords"]:
        if keyword.lower() in instructions.lower():
            rule = age_rules["instruction_keywords"][keyword]
            if rule.get("min_age", 0) > min_age:
                min_age = rule["min_age"]
                reasons.append(f"Instruction '{keyword}' suggests {rule['reason']}")
            if "max_age" in rule:
                max_age = min(max_age, rule["max_age"])

    return {
        "min_age_group": min_age,
        "max_age_group": max_age
    }

# %%
def apply_infer(row):
    if pd.isna(row["min_age_group"]) or pd.isna(row["max_age_group"]):
        result = infer_age(row["food_name"], row["ner_ingredient_csv"], row["instructions"])
        return pd.Series([result["min_age_group"], result["max_age_group"]])
    else:
        return pd.Series([row["min_age_group"], row["max_age_group"]])

# Apply and create new columns
df[["min_age_group", "max_age_group"]] = df.apply(apply_infer, axis=1)

print(df[["food_name", "min_age_group", "max_age_group"]])
# Out:
#                                       food_name  min_age_group  max_age_group
# 0    Edamame and Sweet Potato Dumplings (Oyaki)              7              8
# 1    Chicken, Carrot, and Onion Udon For Babies              7              8
# 2                                 Kinaki Yogurt              7              8
# 3                Natto Oyaki and Grilled Salmon             12             12
# 4                                     Miso Soup              7              8
# ..                                          ...            ...            ...
# 797                    Egg Noodles With Chicken             12             24
# 798                                Fish Patties             12             24
# 799                                Honey Scones             12             24
# 800                    Raisin Chicken Meatballs             12             24
# 801            Green Beans and Rice with Turkey             10             24
#
# [802 rows x 3 columns]

# %% [markdown]
# <p>Format and Fill the Texture</p>

# %%
# Load the module
import importlib

texture_label_path = os.path.join(os.getcwd(), "preprocessing_techniques", "mappers", "texture_label.py")

spec = importlib.util.spec_from_file_location("texture_label", texture_label_path)
texture_label = importlib.util.module_from_spec(spec)
spec.loader.exec_module(texture_label)

# Access the config
texture_config = texture_label.texture_config
pprint(texture_config)
# Out:
# {'family food': {'keywords': ['for adults',
#                               'seasoned for adults',
#                               'serve as is',
#                               'family style',
#                               'serve with family meal',
#                               'adult portion',
#                               'shared with family',
#                               'serve at table',
#                               'table food',
#                               'family dinner',
#                               'not modified',
#                               'no blending',
#                               'whole meal',
#                               'non-baby portion',
#                               'spaghetti',
#                               'pizza',
#                               'fried chicken',
#                               'steak',
#                               'burger',
#                               'taco',
#                               'sandwich',
#                               'soup with chunks',
#                               'stir-fry',
#                               'casserole',
#                               'curry',
#                               'pasta',
#                               'rice bowl',
#                               'ramen',
#                               'noodles',
#                               'salad']},
#  'lumpy texture': {'keywords': ['finely chopped',
#                                 'small cubes',
#                                 'bite-sized pieces',
#                                 'chunks',
#                                 'soft lumps',
#                                 'lumpy texture',
#                                 'pieces about',
#                                 'cut into small pieces',
#                                 'with texture',
#                                 'chunky mix',
#                                 'mixed consistency',
#                                 'partially mashed',
#                                 'chopped carrot',
#                                 'diced sweet potato',
#                                 'chopped onion',
#                                 'chopped chicken',
#                                 'udon noodles',
#                                 'rice pieces',
#                                 'soft tofu chunks',
#                                 'natto',
#                                 'edamame',
#                                 'blueberries',
#                                 'raspberries',
#                                 'melon cubes']},
#  'puree': {'keywords': ['puree',
#                         'blender',
#                         'food processor',
#                         'smooth',
#                         'blend until smooth',
#                         'process until smooth',
#                         'mashed and blended',
#                         'baby puree',
#                         'liquefy',
#                         'whip',
#                         'strain',
#                         'homogenized',
#                         'creamy blend',
#                         'apple puree',
#                         'pear puree',
#                         'banana puree',
#                         'carrot puree',
#                         'sweet potato puree',
#                         'zucchini puree',
#                         'avocado puree',
#                         'yogurt',
#                         'cheese puree',
#                         'prune puree',
#                         'oatmeal puree']},
#  'soft finger food': {'keywords': ['roll into balls',
#                                    'flatten',
#                                    'pan-fry soft',
#                                    'soft dumplings',
#                                    'mash lightly',
#                                    'stick together',
#                                    'formed into shapes',
#                                    'soft finger foods',
#                                    'easy to gum',
#                                    'holdable',
#                                    'pick-up pieces',
#                                    'handheld',
#                                    'rollable',
#                                    'rice ball',
#                                    'potato patty',
#                                    'egg pancake',
#                                    'tofu cube',
#                                    'bread slice',
#                                    'steamed bun',
#                                    'soft dumpling',
#                                    'meatball',
#                                    'pancake',
#                                    'finger bread',
#                                    'mashed banana roll',
#                                    'sweet potato stick',
#                                    'steamed veggie stick']}}

# %%
def parse_instructions(text):
    """
    Extracts numbered steps from a block of text and returns a list of instruction strings.
    """
    instructions = []
    num_instruction = 0
    for line in text.splitlines():
        stripped = line.strip()
        if stripped.startswith(f"{num_instruction + 1}."):
            # Remove the prefix like "1.", "2.", etc.
            instruction = stripped[len(str(num_instruction + 1)) + 1:].strip()
            instructions.append(instruction)
    instructions_str = ' '.join(instructions).lower()
    return instructions_str

# %%
def classify_recipe_texture(recipe_name, ner_ingredients, instructions_list, TEXTURE_KEYWORDS):
    # Step 1: Ensure ingredients are properly processed
    if not isinstance(ner_ingredients, list):
        ingredients_clean = []
    else:
        ingredients_clean = ner_ingredients

    # Step 2: Clean instructions
    instructions_str = parse_instructions(instructions_list)

    # Step 3: Combine all searchable text - ensure EVERYTHING is a string
    combined_text_parts = [str(recipe_name).lower()]
    
    # Safely add each ingredient as a string, skipping None values
    for i in ingredients_clean:
        if i is not None:
            combined_text_parts.append(str(i).lower())
    
    # Add the instructions
    combined_text_parts.append(instructions_str)
    
    # Join all parts with spaces
    combined_text = ' '.join(combined_text_parts)

    # Step 4: Match against each texture keyword set
    for texture_type, data in TEXTURE_KEYWORDS.items():
        for keyword in data["keywords"]:
            if keyword.lower() in combined_text:
                return texture_type

    # Default fallback
    return "NONE"

# %%
df['texture']=''

# %%
def determine_texture(row, TEXTURE_KEYWORDS):
    if pd.isna(row.get("texture")) or row["texture"] in ("", " ", None, "NONE"):
        return classify_recipe_texture(
            recipe_name=row["food_name"],
            ner_ingredients=row["ner_ingredient_csv"],
            instructions_list=row["instructions"],
            TEXTURE_KEYWORDS=TEXTURE_KEYWORDS
        )
    return row["texture"]

df['texture'] = df.apply(determine_texture, axis=1, TEXTURE_KEYWORDS=texture_config)

df[['food_name', 'ner_ingredient', 'texture']].head(10)
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[216], line 11
#
#       3         return classify_recipe_texture(
#
#       4             recipe_name=row["food_name"],
#
#       5             ner_ingredients=row["ner_ingredient_csv"],
#
#       6             instructions_list=row["instructions"],
#
#       7             TEXTURE_KEYWORDS=TEXTURE_KEYWORDS
#
#       8         )
#
#       9     return row["texture"]
#
# ---> 11 df['texture'] = df.apply(determine_texture, axis=1, TEXTURE_KEYWORDS=texture_config)
#
#      13 df[['food_name', 'ner_ingredient', 'texture']].head(10)
#
#
#
# File c:\Users\Helena\Desktop\APU\Semester 5\INV\IR - PROPOSAL\scraping-code\.venv\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#
#   10360 from pandas.core.apply import frame_apply
#
#   10362 op = frame_apply(
#
#   10363     self,
#
#   10364     func=func,
#
#    (...)  10372     kwargs=kwargs,
#
#   10373 )
#
# > 10374 return op.apply().__finalize__(self, method="apply")
#
#
#
# File c:\Users\Helena\Desktop\APU\Semester 5\INV\IR - PROPOSAL\scraping-code\.venv\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#
#     913 elif self.raw:
#
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
#
# --> 916 return self.apply_standard()
#
#
#
# File c:\Users\Helena\Desktop\APU\Semester 5\INV\IR - PROPOSAL\scraping-code\.venv\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#
#    1061 def apply_standard(self):
#
#    1062     if self.engine == "python":
#
# -> 1063         results, res_index = self.apply_series_generator()
#
#    1064     else:
#
#    1065         results, res_index = self.apply_series_numba()
#
#
#
# File c:\Users\Helena\Desktop\APU\Semester 5\INV\IR - PROPOSAL\scraping-code\.venv\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#
#    1078 with option_context("mode.chained_assignment", None):
#
#    1079     for i, v in enumerate(series_gen):
#
#    1080         # ignore SettingWithCopy here in case the user mutates
#
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#
#    1082         if isinstance(results[i], ABCSeries):
#
#    1083             # If we have a view on v, we need to make a copy because
#
#    1084             #  series_generator will swap out the underlying data
#
#    1085             results[i] = results[i].copy(deep=False)
#
#
#
# Cell In[216], line 3, in determine_texture(row, TEXTURE_KEYWORDS)
#
#       1 def determine_texture(row, TEXTURE_KEYWORDS):
#
#       2     if pd.isna(row.get("texture")) or row["texture"] in ("", " ", None, "NONE"):
#
# ----> 3         return classify_recipe_texture(
#
#       4             recipe_name=row["food_name"],
#
#       5             ner_ingredients=row["ner_ingredient_csv"],
#
#       6             instructions_list=row["instructions"],
#
#       7             TEXTURE_KEYWORDS=TEXTURE_KEYWORDS
#
#       8         )
#
#       9     return row["texture"]
#
#
#
# Cell In[215], line 23, in classify_recipe_texture(recipe_name, ner_ingredients, instructions_list, TEXTURE_KEYWORDS)
#
#      20 combined_text_parts.append(instructions_str)
#
#      22 # Join all parts with spaces
#
# ---> 23 combined_text = ' '.join(combined_text_parts)
#
#      25 # Step 4: Match against each texture keyword set
#
#      26 for texture_type, data in TEXTURE_KEYWORDS.items():
#
#
#
# TypeError: sequence item 1: expected str instance, int found
# The Kernel crashed while executing code in the current cell or a previous cell.
#
#
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
#
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
#
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Get the first row (index 0) as a Series
single_row = df.iloc[0]

ingredients_clean = single_row["ner_ingredient"]

# Step 2: Clean instructions
instructions_str = parse_instructions(single_row["instructions"])

# Step 3: Combine all searchable text
combined_text = ' '.join([
    str(single_row["food_name"]).lower(),
    *[str(i).lower() for i in ingredients_clean],
    instructions_str
])

print("Combined Text:")
print(combined_text)
print(ingredients_clean)
print(instructions_str)

# %% [markdown]
# **Determine Origin and Country**

# %% [markdown]
# Classify Category of The Recipe

# %% [markdown]
# Populating Nutrition Value

# %%
# Flatten the list of lists to get all unique ingredients
all_ingredients = set()
for ingredient_list in df['ner_ingredient']:
    if isinstance(ingredient_list, list):
        all_ingredients.update(ingredient_list)

print(f"Total unique ingredients found: {len(all_ingredients)}")
print("Unique ingredients:")
for ingredient in sorted(all_ingredients):
    print(f"- {ingredient}")
# Out:
# Total unique ingredients found: 773
# Unique ingredients:
# - ''salt'
# - 'beef'
# - 'broccoli floret'
# - 'broccoli'
# - 'broth'
# - 'carrot'
# - 'chicken broth'
# - 'chicken]
# - 'corn']
# - 'cucumber'
# - 'garlic'
# - 'ginger'
# - 'mushroom'
# - 'nori seaweed'
# - 'olive oil'
# - 'olive oil']
# - 'rice'
# - 'sesame oil'
# - 'sugar'
# - 'sweet soy sauce'
# - 'white onion'
# - 'yogurt'
# - ['oil'
# - ['rice'
# - [cauliflower''
# - agar agar
# - all purpose flour
# - allpurpose flour
# - almond
# - almond butter
# - aluminum foil
# - ambon banana
# - anchovy
# - annabel karmel pasta
# - apple
# - apple pink lady
# - applesauce
# - apricot
# - aron
# - artichoke
# - asparagus
# - attieké
# - aubergine
# - avocado
# - avocado juice
# - baby
# - baby biscuit
# - baby lemon juice
# - baby oatmeal
# - baby orange juice
# - baby rice
# - baby rusk
# - baby spinach
# - bacon
# - baking powder
# - baking soda
# - balsamic vinegar
# - bambara bean flour
# - banana
# - banana chip
# - banana chunk
# - baobab fruit
# - barley
# - basil
# - basil leaf
# - basmati rice
# - bay
# - bay leaf
# - bay leaf finely
# - bean
# - bean drained
# - bean flour
# - beef
# - beef broth
# - beef chicken broth
# - beef fat oil
# - beef fillet
# - beef oil
# - beef stew meat
# - beef stock
# - beet
# - beetroot
# - berry
# - biscuit
# - black bean
# - black cacao bean
# - black olive
# - black pepper
# - black radish
# - block spinach
# - block tofu
# - blueberry
# - boiled
# - boiling water
# - bombay onion
# - bone
# - boneless white fish fillet
# - bowl
# - bread
# - bread crumb
# - bread crust formula milk cheddar cheese
# - bread flour
# - bread portion
# - breadcrumb
# - breadstic
# - breast formula milk
# - breast milk
# - brioche
# - broccoli
# - broccoli floret
# - broccoli floret carrot formula milk fine rice flour
# - broccoli water
# - broth
# - brown rice
# - brown sugar
# - bumboo canola oil
# - bumboo chicken fat oil
# - bumboo teri bubuk
# - bumboo teri bubuk sesame seed
# - burbot
# - butter
# - butter bean
# - butterbean
# - buttercup squash
# - butternut
# - butternut pumpkin
# - butternut squash
# - button mushroom
# - cabbage
# - candy
# - cane sugar
# - canola oil
# - canola sunflower oil
# - cantaloupe
# - cantaloupe melon
# - carrot
# - carrot finely
# - carrot water cornstarch
# - cashew
# - cashew butter
# - cassava
# - cassava flour
# - caster sugar
# - catfish
# - catfish mince
# - walnut oil
# - water
# - water bay leaf
# - water breast milk formula milk
# - water olive oil
# - water spinach
# - watermelon
# - weak chicken stock
# - wedge courgette
# - wedge red pepper
# - wheat bisk
# - wheat flour
# - wheat vermicelli
# - white bread
# - white bread roll
# - white flour
# - white guava
# - white kidney bean
# - white leek
# - white mushroom
# - white onion
# - white pepper
# - white radish
# - white rice
# - white rice portion
# - white shallot
# - white sugar
# - white tofu
# - whole milk ricotta
# - whole wheat pasta
# - wholemeal bread
# - winter melon
# - worcestershire sauce
# - yeast
# - yellow cornflour
# - yellow onion
# - yellow pepper
# - yellow pumpkin
# - yellow split pea
# - yellow squash
# - yellow sweet corn
# - yellow sweet potato
# - yoghurt
# - yogurt
# - zucchini
# - â tomato seed

# %%
# Load the module
import importlib

category_path = os.path.join(os.getcwd(), "preprocessing_techniques", "mappers", "category_dict.py")

spec = importlib.util.spec_from_file_location("category", category_path)
category_file = importlib.util.module_from_spec(spec)
spec.loader.exec_module(category_file)

# Access the config
dietary_tags  = category_file.dietary_tags
pprint(dietary_tags)
# Out:
# {'dairy_free': {'excluded_allergen_groups': ['milk'],
#                 'excluded_ingredients': ['cheese',
#                                          'butter',
#                                          'yogurt',
#                                          'milk',
#                                          'whey',
#                                          'casein',
#                                          'cream',
#                                          'ice cream']},
#  'egg_free': {'excluded_allergen_groups': ['egg'],
#               'excluded_ingredients': ['eggs',
#                                        'egg white',
#                                        'egg yolk',
#                                        'lecithin',
#                                        'omelette']},
#  'gluten_free': {'excluded_allergen_groups': ['gluten'],
#                  'excluded_ingredients': ['wheat',
#                                           'barley',
#                                           'rye',
#                                           'bread',
#                                           'pasta',
#                                           'semolina',
#                                           'crackers',
#                                           'cookies',
#                                           'cereals',
#                                           'panko',
#                                           'flour (wheat)',
#                                           'beer']},
#  'halal': {'excluded_allergen_groups': ['pork'],
#            'excluded_ingredients': ['pork',
#                                     'bacon',
#                                     'ham',
#                                     'gelatin',
#                                     'alcohol',
#                                     'non_halal_meat'],
#            'notes': 'Follows halal food laws — no pork, alcohol, or non-halal '
#                     'meat'},
#  'non_halal': {'notes': 'Contains ingredients not allowed in halal diet',
#                'required_ingredients': ['pork',
#                                         'bacon',
#                                         'ham',
#                                         'gelatin',
#                                         'alcohol',
#                                         'non_halal_meat']},
#  'non_veg': {'notes': 'Default tag for any recipe containing meat or fish (no '
#                       'exclusions)'},
#  'nut_free': {'excluded_allergen_groups': ['nuts'],
#               'excluded_ingredients': ['almonds',
#                                        'cashews',
#                                        'walnuts',
#                                        'peanuts',
#                                        'hazelnuts',
#                                        'pecans',
#                                        'nut butter',
#                                        'nut milk',
#                                        'trail mix']},
#  'pescetarian': {'allowed_categories': ['plant_based',
#                                         'dairy',
#                                         'egg',
#                                         'seafood'],
#                  'excluded_allergen_groups': [],
#                  'excluded_ingredients': ['meat',
#                                           'bacon',
#                                           'gelatin',
#                                           'pork',
#                                           'lamb',
#                                           'chicken',
#                                           'beef'],
#                  'notes': 'Contains fish but no other meats.'},
#  'soy_free': {'excluded_allergen_groups': ['soy'],
#               'excluded_ingredients': ['soy',
#                                        'tofu',
#                                        'edamame',
#                                        'soy sauce',
#                                        'soy milk',
#                                        'tempeh',
#                                        'miso']},
#  'vegan': {'allowed_categories': ['plant_based'],
#            'excluded_allergen_groups': ['milk', 'egg', 'fish', 'shellfish'],
#            'excluded_ingredients': ['meat',
#                                     'chicken',
#                                     'beef',
#                                     'pork',
#                                     'lamb',
#                                     'bacon',
#                                     'gelatin',
#                                     'eggs',
#                                     'cheese',
#                                     'butter',
#                                     'yogurt',
#                                     'whey',
#                                     'casein',
#                                     'lard',
#                                     'milk',
#                                     'honey'],
#            'notes': 'No animal products. Safe only if choking hazard-free.'},
#  'vegetarian': {'allowed_categories': ['plant_based', 'dairy', 'egg'],
#                 'excluded_allergen_groups': ['fish', 'shellfish'],
#                 'excluded_ingredients': ['meat',
#                                          'chicken',
#                                          'beef',
#                                          'pork',
#                                          'lamb',
#                                          'gelatin',
#                                          'pork',
#                                          'bacon',
#                                          'ham',
#                                          'cod',
#                                          'salmon',
#                                          'tuna',
#                                          'shellfish',
#                                          'shrimp',
#                                          'lobster',
#                                          'crab',
#                                          'prawn'],
#                 'notes': 'May contain dairy or eggs, but no meat.'}}

# %%
def classify_recipe_categories(recipe_data, dietary_tags):
    """
    Classifies a recipe into multiple dietary preference categories.
    
    Parameters:
        recipe_data (dict): Must contain:
            - 'ner_ingredients' (list or str)
            - 'allergens' (list of detected allergen groups like ['milk', 'soy'])
            - 'texture' (optional, for stage-based filtering)
        
        dietary_tags (dict): Dictionary mapping diet name → rules
    
    Returns:
        dict: {
            "matched_tags": list[str]  # e.g., ['vegan', 'soy', 'halal']
        }
    """
    ner_ingredient = recipe_data.get("ner_ingredient", [])
    # Normalize ingredients (make sure they're lowercase and clean)
    cleaned_ingredients = [str(i).strip().lower() for i in ner_ingredient if i]
    combined_text = ' '.join(cleaned_ingredients)

    detected_allergens = recipe_data.get("allergen", [])
    allergen = [str(i).strip().lower() for i in detected_allergens if i]
    allergen_text = ' '.join(allergen).lower()
    matched_tags = []

    for tag, rules in dietary_tags.items():
        exclude_found = False

        # Step 1: Check excluded ingredients
        if "excluded_ingredients" in rules:
            for word in rules["excluded_ingredients"]:
                if word.lower() in combined_text:
                    exclude_found = True
                    break

        # Step 2: Check excluded allergen groups
        if "excluded_allergen_groups" in rules:
            for group in rules["excluded_allergen_groups"]:
                if group in allergen_text:
                    exclude_found = True
                    break

        # Step 3: Required ingredients check (for non_halal etc.)
        if "required_ingredients" in rules:
            required_match = any(word in combined_text for word in rules["required_ingredients"])
            if not required_match:
                continue  # Skip unless match found

        # If no exclusion → match this tag
        if not exclude_found:
            matched_tags.append(tag)
            
    if not matched_tags and "non_veg" in dietary_tags:
        matched_tags.append("non_veg")    
    
    
    return matched_tags

# %%
def classify_recipe(recipe_data, dietary_tags):
    ner_ingredient = recipe_data.get("ner_ingredient", [])
    # Normalize ingredients (make sure they're lowercase and clean)
    cleaned_ingredients = [str(i).strip().lower() for i in ner_ingredient if i]
    combined_text = ' '.join(cleaned_ingredients)

    detected_allergens = recipe_data.get("allergen", [])
    allergen = [str(i).strip().lower() for i in detected_allergens if i]
    allergen_text = ' '.join(allergen).lower()

    matched_tags = []

    # Step 1: Match all possible tags
    for tag, rules in dietary_tags.items():
        exclude_found = False

        # Step 1a: Check excluded ingredients
        if "excluded_ingredients" in rules:
            for word in rules["excluded_ingredients"]:
                if word.lower() in combined_text:
                    exclude_found = True
                    break

        # Step 1b: Check excluded allergen groups
        if "excluded_allergen_groups" in rules:
            for group in rules["excluded_allergen_groups"]:
                if group in allergen_text:
                    exclude_found = True
                    break

        # Step 1c: Required ingredients check (e.g., for non_halal)
        if "required_ingredients" in rules:
            required_match = any(word in combined_text for word in rules["required_ingredients"])
            if not required_match:
                continue

        if not exclude_found:
            matched_tags.append(tag)

    # Define categories
    GENERAL_DIET_TAGS = ["vegan", "vegetarian", "pescetarian", "non_veg"]
    RELIGIOUS_TAGS = ["halal", "non_halal"]
    ALLERGEN_TAGS = ["dairy_free", "egg_free", "soy_free", "nut_free", "gluten_free"]

    result = {
        "general_diet": None,
        "religious_tag": None,
        "allergen_tags": [],
    }

    # Step 2: Select only one general diet (priority-based)
    for tag in GENERAL_DIET_TAGS:
        if tag in matched_tags:
            result["general_diet"] = tag
            break
    else:
        # Fallback (shouldn't happen unless none of the 4 are valid)
        result["general_diet"] = "non_veg"

    # Step 3: Select at most one religious tag (prefer halal over non_halal)
    for tag in RELIGIOUS_TAGS:
        if tag in matched_tags:
            result["religious_tag"] = tag
            break

    # Step 4: Select all applicable allergen-friendly tags
    result["allergen_tags"] = [tag for tag in matched_tags if tag in ALLERGEN_TAGS]

    values = []
    
    # Add general diet if present
    if result.get("general_diet"):
        values.append(result["general_diet"])
    
    # Add religious tag if present
    if result.get("religious_tag"):
        values.append(result["religious_tag"])
    
    # Add allergen tags if present
    allergen_tags = result.get("allergen_tags", [])
    if allergen_tags:
        values.extend(allergen_tags)
    
    # Join all values with commas
    return ", ".join(values)

    return result

# %%
sample_row = df.iloc[0].copy()  
classified_tags = classify_recipe(sample_row, dietary_tags)
print("Classified Tags:")
print(classified_tags)
# Out:
# Classified Tags:
# vegan, halal, dairy_free, egg_free, nut_free, gluten_free

# %%
df['dietary_tags'] = df.apply(
    lambda row: classify_recipe(row, dietary_tags),
    axis=1)

df[['ner_ingredient', 'dietary_tags', 'choking_hazard']].head(10)
# Out:
#                                       ner_ingredient  \
# 0         [sweet potato, edamame, cornstarch, water]
# 1  [onion, chicken breast, udon thin, dashi, clea...
# 2                            [yogurt, soybean flour]
# 3  [japanese rice, natto, long onion, egg, butter...
# 4                          [dashi, tofu, miso paste]
# 5                                         [zucchini]
# 6                [apple pink lady, honeycrisp, pear]
# 7                              [baby oatmeal, prune]
# 8   [yellow sweet potato, breast milk, formula milk]
# 9  [carrot, potato, cheese, coriander, oil, water...
#
#                                         dietary_tags choking_hazard
# 0  vegan, halal, dairy_free, egg_free, nut_free, ...           None
# 1  non_veg, halal, dairy_free, egg_free, soy_free...           None
# 2              vegetarian, halal, egg_free, nut_free           None
# 3  pescetarian, halal, egg_free, soy_free, nut_fr...           None
# 4  vegan, halal, dairy_free, egg_free, nut_free, ...           None
# 5  vegan, halal, dairy_free, egg_free, soy_free, ...           None
# 6  vegetarian, halal, dairy_free, egg_free, soy_f...           None
# 7  vegan, halal, dairy_free, egg_free, soy_free, ...           None
# 8  vegetarian, halal, egg_free, soy_free, nut_fre...           None
# 9  vegetarian, halal, egg_free, soy_free, nut_fre...           None

# %%
print(f"Current working directory: {os.getcwd()}")
print(f"Processing directory: {processing_dir}")
print(f"Python path: {sys.path}")
# Out:
# Current working directory: c:\Users\Helena\Desktop\APU\Semester 5\INV\IR - PROPOSAL\scraping-code\baby-food-recom-data-ai\01_DataPreprocessing
# Processing directory: c:\Users\Helena\Desktop\APU\Semester 5\INV\IR - PROPOSAL\scraping-code\baby-food-recom-data-ai\01_DataPreprocessing\preprocessing_techniques
# Python path: ['C:\\Program Files\\Python311\\python311.zip', 'C:\\Program Files\\Python311\\DLLs', 'C:\\Program Files\\Python311\\Lib', 'C:\\Program Files\\Python311', 'c:\\Users\\Helena\\Desktop\\APU\\Semester 5\\INV\\IR - PROPOSAL\\scraping-code\\.venv', '', 'c:\\Users\\Helena\\Desktop\\APU\\Semester 5\\INV\\IR - PROPOSAL\\scraping-code\\.venv\\Lib\\site-packages', 'c:\\Users\\Helena\\Desktop\\APU\\Semester 5\\INV\\IR - PROPOSAL\\scraping-code\\.venv\\Lib\\site-packages\\win32', 'c:\\Users\\Helena\\Desktop\\APU\\Semester 5\\INV\\IR - PROPOSAL\\scraping-code\\.venv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\Helena\\Desktop\\APU\\Semester 5\\INV\\IR - PROPOSAL\\scraping-code\\.venv\\Lib\\site-packages\\Pythonwin', 'c:\\Users\\Helena\\Desktop\\APU\\Semester 5\\INV\\IR - PROPOSAL\\scraping-code\\baby-food-recom-data-ai\\01_DataPreprocessing\\preprocessing_techniques']

# %%
# Fix the import statement - it should be "from mappers..." not "pers..."
from mappers.origin_region_mapper import country_food_map
pprint(country_food_map)
# Out:
# {'Algeria': {'category': 'Mediterranean', 'flag': 'dz'},
#  'America': {'category': 'American', 'flag': 'us'},
#  'Angola': {'category': 'African', 'flag': 'ao'},
#  'Argentina': {'category': 'Latin American', 'flag': 'ar'},
#  'Australia': {'category': 'Oceanic', 'flag': 'au'},
#  'Austria': {'category': 'Western / European', 'flag': 'at'},
#  'Bahamas': {'category': 'Caribbean', 'flag': 'bs'},
#  'Bangladesh': {'category': 'Indian', 'flag': 'bd'},
#  'Barbados': {'category': 'Caribbean', 'flag': 'bb'},
#  'Belgium': {'category': 'Western / European', 'flag': 'be'},
#  'Bhutan': {'category': 'Indian', 'flag': 'bt'},
#  'Brazil': {'category': 'Latin American', 'flag': 'br'},
#  'Cambodia': {'category': 'Southeast Asian', 'flag': 'kh'},
#  'Chile': {'category': 'Latin American', 'flag': 'cl'},
#  'China': {'category': 'Asian', 'flag': 'cn'},
#  'Colombia': {'category': 'Latin American', 'flag': 'co'},
#  'Cuba': {'category': 'Latin American', 'flag': 'cu'},
#  'Dominican Republic': {'category': 'Latin American', 'flag': 'do'},
#  'Egypt': {'category': 'Mediterranean', 'flag': 'eg'},
#  'Ethiopia': {'category': 'African', 'flag': 'et'},
#  'Fiji': {'category': 'Oceanic', 'flag': 'fj'},
#  'France': {'category': 'Western / European', 'flag': 'fr'},
#  'Germany': {'category': 'Western / European', 'flag': 'de'},
#  'Greece': {'category': 'Mediterranean', 'flag': 'gr'},
#  'Haiti': {'category': 'Caribbean', 'flag': 'ht'},
#  'India': {'category': 'Indian', 'flag': 'in'},
#  'Indonesia': {'category': 'Southeast Asian', 'flag': 'id'},
#  'Iran': {'category': 'Middle Eastern', 'flag': 'ir'},
#  'Israel': {'category': 'Middle Eastern', 'flag': 'il'},
#  'Italy': {'category': 'Mediterranean', 'flag': 'it'},
#  'Jamaica': {'category': 'Caribbean', 'flag': 'jm'},
#  'Japan': {'category': 'Asian', 'flag': 'jp'},
#  'Jordan': {'category': 'Middle Eastern', 'flag': 'jo'},
#  'Kenya': {'category': 'African', 'flag': 'ke'},
#  'Laos': {'category': 'Southeast Asian', 'flag': 'la'},
#  'Lebanon': {'category': 'Middle Eastern', 'flag': 'lb'},
#  'Malaysia': {'category': 'Southeast Asian', 'flag': 'my'},
#  'Mexico': {'category': 'American', 'flag': 'mx'},
#  'Mongolia': {'category': 'Asian', 'flag': 'mn'},
#  'Morocco': {'category': 'Mediterranean', 'flag': 'ma'},
#  'Myanmar': {'category': 'Southeast Asian', 'flag': 'mm'},
#  'Nepal': {'category': 'Indian', 'flag': 'np'},
#  'Netherlands': {'category': 'Western / European', 'flag': 'nl'},
#  'New Zealand': {'category': 'Oceanic', 'flag': 'nz'},
#  'Nigeria': {'category': 'African', 'flag': 'ng'},
#  'Pakistan': {'category': 'Indian', 'flag': 'pk'},
#  'Papua New Guinea': {'category': 'Oceanic', 'flag': 'pg'},
#  'Peru': {'category': 'Latin American', 'flag': 'pe'},
#  'Philippines': {'category': 'Southeast Asian', 'flag': 'ph'},
#  'Portugal': {'category': 'Western / European', 'flag': 'pt'},
#  'Puerto Rico': {'category': 'American', 'flag': 'pr'},
#  'Samoa': {'category': 'Oceanic', 'flag': 'ws'},
#  'Saudi Arabia': {'category': 'Middle Eastern', 'flag': 'sa'},
#  'Senegal': {'category': 'African', 'flag': 'sn'},
#  'Singapore': {'category': 'Southeast Asian', 'flag': 'sg'},
#  'South Africa': {'category': 'African', 'flag': 'za'},
#  'South Korea': {'category': 'Asian', 'flag': 'kr'},
#  'Spain': {'category': 'Mediterranean', 'flag': 'es'},
#  'Sri Lanka': {'category': 'Indian', 'flag': 'lk'},
#  'Switzerland': {'category': 'Western / European', 'flag': 'ch'},
#  'Syria': {'category': 'Middle Eastern', 'flag': 'sy'},
#  'Tanzania': {'category': 'African', 'flag': 'tz'},
#  'Thailand': {'category': 'Southeast Asian', 'flag': 'th'},
#  'Timor-Leste': {'category': 'Southeast Asian', 'flag': 'tl'},
#  'Tonga': {'category': 'Oceanic', 'flag': 'to'},
#  'Trinidad and Tobago': {'category': 'Caribbean', 'flag': 'tt'},
#  'Tunisia': {'category': 'Mediterranean', 'flag': 'tn'},
#  'Turkey': {'category': 'Middle Eastern', 'flag': 'tr'},
#  'UK': {'category': 'Western / European', 'flag': 'gb'},
#  'United Arab Emirates': {'category': 'Middle Eastern', 'flag': 'ae'},
#  'United Kingdom': {'category': 'Western / European', 'flag': 'gb'},
#  'United States': {'category': 'American', 'flag': 'us'},
#  'Vietnam': {'category': 'Southeast Asian', 'flag': 'vn'},
#  'uk': {'category': 'Western / European', 'flag': 'gb'},
#  'usa': {'category': 'American', 'flag': 'us'}}

# %%
def get_flag_and_region(country_name):
    """
    Given a country name, returns flag code and region.
    If not found, returns ('unknown', 'Uncategorized').
    """
    country = country_name.title()
    info = country_food_map.get(country, {})
    flag = info.get("flag", "unknown")
    region = info.get("category", "Uncategorized")
    return flag, region

# %%
#null value in origin
df['origin'].isnull().sum()

# Initialize new column if it doesn't exist
if 'flag_code' not in df.columns:
    df['flag_code'] = ""

# Create list to store results
flags = []
regions = []

for _, row in df.iterrows():
    origin = row['origin']
    
    if pd.isna(origin):  # Skip missing origins
        flags.append("")
        regions.append("")
        continue
    
    flag, region = get_flag_and_region(origin)
    flags.append(flag)
    regions.append(region)

# Assign new columns back to DataFrame
df['flag_code'] = flags
df['region'] = regions

# %%
df.shape
df[['origin', 'flag_code', 'region']].head(10)
# Out:
#       origin flag_code           region
# 0     Japan    unknown    Uncategorized
# 1      Japan        jp            Asian
# 2      Japan        jp            Asian
# 3      Japan        jp            Asian
# 4      Japan        jp            Asian
# 5    America        us         American
# 6    America        us         American
# 7    America        us         American
# 8  Indonesia        id  Southeast Asian
# 9     Bhutan        bt           Indian

# %% [markdown]
# <p>Formatting Prep, Cook, Difficulty</p>

# %%
# Extract only the digits from time values (e.g., "15 min" -> 15)
def remove_min(text):
    if pd.isna(text):
        return None
    
    import re
    # Find all digits in the text
    match = re.search(r'\d+', str(text))
    if match:
        return int(match.group())
    return None

# Apply the function to prep_time and cook_time columns
df['prep_time'] = df['prep_time'].apply(remove_min)
df['cook_time'] = df['cook_time'].apply(remove_min)

df[['prep_time', 'cook_time']].head(10)
# Out:
#    prep_time  cook_time
# 0       10.0        5.0
# 1        5.0        6.0
# 2        2.0        3.0
# 3        NaN        NaN
# 4        2.0        3.0
# 5        NaN        NaN
# 6        NaN        NaN
# 7        NaN        NaN
# 8       10.0       15.0
# 9        NaN       30.0

# %%
import codecs

def parse_ingredients(text):
    """
    Extracts lines that start with '-' from a block of text and returns a list of ingredients.
    """
    ingredients = []
    num_ingredient=0
    # print(text)
    for line in text.split('\n'):
        stripped = line.strip()
        if stripped.startswith('-'):
            ingredients.append(stripped[1:].strip())
            num_ingredient+=1
    return num_ingredient


def parse_instructions(text):
    """
    Extracts numbered steps from a block of text and returns a list of instruction strings.
    """
    instructions = []
    num_instruction=0
    for line in text.splitlines():
        stripped = line.strip()
        if stripped.startswith(str(num_instruction+1)+'.'):
            instructions.append(stripped[len(str(num_instruction+1))+1:].strip())
            num_instruction+=1
    return num_instruction

# %%
def estimate_difficulty(ingredients, instructions):
    ingredients = codecs.decode(ingredients, 'unicode_escape')
    instructions = codecs.decode(instructions, 'unicode_escape')
    num_ingredients = parse_ingredients(ingredients)
    num_steps = parse_instructions(instructions)
    # print(f"Number of ingredients: {num_ingredients}")
    # print(f"Number of steps: {num_steps}")
    if num_ingredients <= 4 and num_steps <= 5:
        return "Easy"
    elif num_ingredients <= 8 and num_steps <= 8:
        return "Medium"
    else:
        return "Hard"

# %%
# Estimate difficulty
df['difficulty'] = df.apply(
    lambda row: estimate_difficulty(row['ingredient'], row['instructions']),
    axis=1
)

df[['food_name', 'difficulty']].head(10)
# Out:
#                                      food_name difficulty
# 0   Edamame and Sweet Potato Dumplings (Oyaki)     Medium
# 1   Chicken, Carrot, and Onion Udon For Babies     Medium
# 2                                Kinaki Yogurt       Easy
# 3               Natto Oyaki and Grilled Salmon     Medium
# 4                                    Miso Soup     Medium
# 5                               Zucchini puree       Easy
# 6                         Apple and pear sauce       Easy
# 7                     Baby oatmeal with prunes       Easy
# 8  Yellow Sweet Potato Puree (Pure Ubi Kuning)       Easy
# 9                   Vegetable and Cheese Puree     Medium

# %%
#Formatting the prep and cook time
import re

def extract_integer(value):
    match = re.search(r'\d+', str(value))
    if match:
        return int(match.group())
    return None

df['prep_time'] = df['prep_time'].apply(extract_integer)
df['cook_time'] = df['cook_time'].apply(extract_integer)

df[['prep_time', 'cook_time']].head(10)
# Out:
#    prep_time  cook_time
# 0       10.0        5.0
# 1        5.0        6.0
# 2        2.0        3.0
# 3        NaN        NaN
# 4        2.0        3.0
# 5        NaN        NaN
# 6        NaN        NaN
# 7        NaN        NaN
# 8       10.0       15.0
# 9        NaN       30.0

# %% [markdown]
# <p>Determine Choking Hazard and Tips</p>

# %%
# Load the module
import importlib

choking_hazard_path = os.path.join(os.getcwd(), "preprocessing_techniques", "mappers", "choking_hazard_classifiers.py")

spec = importlib.util.spec_from_file_location("choking_hazard", choking_hazard_path)
choking_hazard_file = importlib.util.module_from_spec(spec)
spec.loader.exec_module(choking_hazard_file)

# Access the config
choking_hazard  = choking_hazard_file.choking_hazard
pprint(choking_hazard)
# Out:
# {'all_choking_hazards': ['whole blueberries',
#                          'grapes',
#                          'whole cherry tomatoes',
#                          'whole strawberries',
#                          'raw apple chunks',
#                          'raw pear chunks',
#                          'whole grapes',
#                          'whole raspberries',
#                          'whole blackberries',
#                          'whole peaches',
#                          'melon balls',
#                          'raw carrot sticks',
#                          'raw bell pepper',
#                          'raw cucumber',
#                          'raw zucchini',
#                          'raw broccoli florets',
#                          'raw cauliflower',
#                          'raw green beans',
#                          'whole edamame',
#                          'whole peas',
#                          'whole lentils',
#                          'whole chickpeas',
#                          'whole kidney beans',
#                          'soybeans',
#                          'natto',
#                          'udon noodles',
#                          'rice cakes',
#                          'gummy candies',
#                          'marshmallows',
#                          'caramels',
#                          'chewing gum',
#                          'popcorn',
#                          'chicken chunks',
#                          'beef cubes',
#                          'turkey cubes',
#                          'salmon bites',
#                          'hot dogs',
#                          'sausage slices',
#                          'large meatballs',
#                          'whole almonds',
#                          'walnuts',
#                          'peanuts',
#                          'cashews',
#                          'sunflower seeds',
#                          'chia seeds',
#                          'flaxseeds',
#                          'honeycomb',
#                          'hard candy',
#                          'jelly beans',
#                          'gummy bears',
#                          'pretzels',
#                          'bread crusts',
#                          'toasted bread cubes',
#                          'crackers',
#                          'not cooked until soft',
#                          'left whole',
#                          'cut into large pieces',
#                          'bake instead of steam',
#                          'not mashed',
#                          'not pureed'],
#  'beans_and_legumes': ['whole edamame',
#                        'whole peas',
#                        'whole lentils',
#                        'whole chickpeas',
#                        'whole kidney beans',
#                        'soybeans',
#                        'natto'],
#  'hard_raw_vegetables': ['raw carrot sticks',
#                          'raw bell pepper',
#                          'raw cucumber',
#                          'raw zucchini',
#                          'raw broccoli florets',
#                          'raw cauliflower',
#                          'raw green beans'],
#  'meat_chunks': ['chicken chunks',
#                  'beef cubes',
#                  'turkey cubes',
#                  'salmon bites',
#                  'hot dogs',
#                  'sausage slices',
#                  'large meatballs'],
#  'nuts_and_seeds': ['whole almonds',
#                     'walnuts',
#                     'peanuts',
#                     'cashews',
#                     'sunflower seeds',
#                     'chia seeds',
#                     'flaxseeds',
#                     'honeycomb'],
#  'other_choking_risks': ['hard candy',
#                          'jelly beans',
#                          'gummy bears',
#                          'pretzels',
#                          'bread crusts',
#                          'toasted bread cubes',
#                          'crackers'],
#  'sticky_slippery_foods': ['udon noodles',
#                            'rice cakes',
#                            'gummy candies',
#                            'marshmallows',
#                            'caramels',
#                            'chewing gum',
#                            'popcorn'],
#  'unsafe_preparation_methods': ['not cooked until soft',
#                                 'left whole',
#                                 'cut into large pieces',
#                                 'bake instead of steam',
#                                 'not mashed',
#                                 'not pureed'],
#  'whole_or_firm_fruits': ['whole blueberries',
#                           'grapes',
#                           'whole cherry tomatoes',
#                           'whole strawberries',
#                           'raw apple chunks',
#                           'raw pear chunks',
#                           'whole grapes',
#                           'whole raspberries',
#                           'whole blackberries',
#                           'whole peaches',
#                           'melon balls']}

# %%
def has_choking_hazard(row):
    """
    Detects baby food choking hazards using NER ingredients + instructions.
    
    Parameters:
        row: DataFrame row with ner_ingredient, ingredient, and instructions
    
    Returns:
        str: "Yes" or "No"
    """
    # Step 1: Get & normalize ingredients
    ner_ingredients = row.get("ner_ingredient", [])
    original_ingredients = row.get("ingredient", "")
    instructions = row.get("instructions", "")
    
    # Convert list of ingredients to string for search
    ner_ingredients_text = ' '.join([str(i).lower() for i in ner_ingredients])
    
    # Step 2: Clean instructions
    cleaned_instructions = ""
    if instructions:
        if callable(getattr(instructions, 'lower', None)):
            cleaned_instructions = instructions.lower()
    
    # Step 3: Combine all searchable text
    combined_text = ' '.join([
        ner_ingredients_text,
        str(original_ingredients).lower(),
        cleaned_instructions
    ])
    
    # Step 4: Match against all_choking_hazards
    matched_categories = []
    for category, hazards in choking_hazard.items():
        if category == "all_choking_hazards":
            # Optional: Add a general safety fallback
            for hazard in hazards:
                if hazard in combined_text and "all_choking_hazards" not in matched_categories:
                    matched_categories.append("all_choking_hazards")
                    break  # No need to keep checking once match found
        else:
            # Regular categories like fruits, veggies, etc.
            for hazard in hazards:
                if hazard in combined_text and category not in matched_categories:
                    matched_categories.append(category)
                    break  # Break inner loop after first match in this category
    
    if matched_categories:
        return "Yes"
    else:
        return "No"

# %%
# Apply to every row in the DataFrame
df['choking_hazards'] = df.apply(has_choking_hazard, axis=1)
df[['food_name', 'ner_ingredient', 'choking_hazards']].head(10)
# Out:
#                                      food_name  \
# 0   Edamame and Sweet Potato Dumplings (Oyaki)
# 1   Chicken, Carrot, and Onion Udon For Babies
# 2                                Kinaki Yogurt
# 3               Natto Oyaki and Grilled Salmon
# 4                                    Miso Soup
# 5                               Zucchini puree
# 6                         Apple and pear sauce
# 7                     Baby oatmeal with prunes
# 8  Yellow Sweet Potato Puree (Pure Ubi Kuning)
# 9                   Vegetable and Cheese Puree
#
#                                       ner_ingredient choking_hazards
# 0         [sweet potato, edamame, cornstarch, water]              No
# 1  [onion, chicken breast, udon thin, dashi, clea...              No
# 2                            [yogurt, soybean flour]              No
# 3  [japanese rice, natto, long onion, egg, butter...             Yes
# 4                          [dashi, tofu, miso paste]              No
# 5                                         [zucchini]              No
# 6                [apple pink lady, honeycrisp, pear]              No
# 7                              [baby oatmeal, prune]              No
# 8   [yellow sweet potato, breast milk, formula milk]              No
# 9  [carrot, potato, cheese, coriander, oil, water...              No

# %%
def convert_escaped_newlines(df):
    """
    Convert escaped newlines (\\n) to real newlines for Excel display
    """
    text_columns = ['ingredient', 'instructions', 'tips']
    
    for col in text_columns:
        if col in df.columns:
            # Replace escaped newlines with actual newlines
            df[col] = df[col].apply(
                lambda x: x.replace('\\n', '\n') if isinstance(x, str) else x
            )
    
    return df

# Apply the conversion right before saving
df = convert_escaped_newlines(df)

# Then save
df.to_excel("1st-dataset.xlsx", index=False)
print("✅ DataFrame saved to 'baby_food_recipes.xlsx'")

# %% [markdown]
# **Populating Nutrition Data**

# %%
# Flatten the list of lists to get all unique ingredients
all_ingredients = set()
for ingredient_list in df['ner_ingredient']:
    if isinstance(ingredient_list, list):
        all_ingredients.update(ingredient_list)

print(f"Total unique ingredients found: {len(all_ingredients)}")
print("Unique ingredients:")
for ingredient in sorted(all_ingredients):
    print(f"- {ingredient}")
# Out:
# Total unique ingredients found: 773
# Unique ingredients:
# - ''salt'
# - 'beef'
# - 'broccoli floret'
# - 'broccoli'
# - 'broth'
# - 'carrot'
# - 'chicken broth'
# - 'chicken]
# - 'corn']
# - 'cucumber'
# - 'garlic'
